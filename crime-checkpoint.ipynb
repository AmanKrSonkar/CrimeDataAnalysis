# %%
import pandas as pd
from matplotlib import pyplot as plt
import os

# %%
pwd
# Out:
# 'C:\\Users\\Prashant\\Desktop\\New folder'

# %%
data = pd.read_csv(r'C:\Users\Prashant\Desktop\New folder\crimes.csv')

# %%
print(data.head())
# Out:
#          STATE_UT   DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0   A & N ISLANDS    ANDAMAN  2001      13                  0
# 1   A & N ISLANDS    NICOBAR  2001       0                  0
# 2  ANDHRA PRADESH   ADILABAD  2001     101                 60
# 3  ANDHRA PRADESH  ANANTAPUR  2001     151                125
# 4  ANDHRA PRADESH   CHITTOOR  2001     101                 57
#
#    CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# 0                                          0     3               0
# 1                                          0     0               0
# 2                                         17    50               0
# 3                                          1    23               0
# 4                                          2    27               0
#
#    OTHER_RAPE  KIDNAPPING_&_ABDUCTION  ...  ARSON  HURT_GREVIOUS HURT  \
# 0           3                       2  ...      4                 113
# ...

# %%
x=data.loc[data['YEAR']==2001 ]
x
# Out:
#            STATE_UT         DISTRICT  YEAR  MURDER  ATTEMPT_TO_MURDER  \
# 0     A & N ISLANDS          ANDAMAN  2001      13                  0
# 1     A & N ISLANDS          NICOBAR  2001       0                  0
# 2    ANDHRA PRADESH         ADILABAD  2001     101                 60
# 3    ANDHRA PRADESH        ANANTAPUR  2001     151                125
# 4    ANDHRA PRADESH         CHITTOOR  2001     101                 57
# ..              ...              ...   ...     ...                ...
# 677     WEST BENGAL            NADIA  2001     124                  0
# 678     WEST BENGAL          PURULIA  2001      69                  0
# 679     WEST BENGAL   SEALDAH G.R.P.  2001      23                  6
# 680     WEST BENGAL  SILIGURI G.R.P.  2001       2                  0
# 681     WEST BENGAL   UTTAR DINAJPUR  2001      36                 51
#
#      CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER  RAPE  CUSTODIAL_RAPE  \
# ...

# %%
plt.plot(data.YEAR,data.MURDER)
plt.xlabel('YEAR')
plt.ylabel('MURDER')
plt.show()

# %%
plt.plot(data.YEAR,data.RAPE)
plt.xlabel('YEAR')
plt.ylabel('RAPE')
plt.show()

# %%
plt.plot(data.YEAR,data.INSULT_TO_MODESTY_OF_WOMEN)
plt.xlabel('YEAR')
plt.ylabel('INSULT TO MODESTY OF WOMEN')
plt.show()

# %%
plt.plot(data.YEAR,data.ATTEMPT_TO_MURDER)
plt.xlabel('YEAR')
plt.ylabel('ATTEMPT TO MURDER')
plt.show()

# %%
x=data.loc[data['YEAR']==2001]
y=x.MURDER
q=y.describe()
print(q)
# Out:
# count    682.000000
# mean      53.884164
# std       53.375293
# min        0.000000
# 25%       21.000000
# 50%       40.000000
# 75%       71.000000
# max      547.000000
# Name: MURDER, dtype: float64

# %%
data.describe()
# Out:
#               YEAR       MURDER  ATTEMPT_TO_MURDER  \
# count  8609.000000  8609.000000        8609.000000
# mean   2006.635149    47.479150          41.497735
# std       3.464051    46.207278          52.757514
# min    2001.000000     0.000000           0.000000
# 25%    2004.000000    18.000000          10.000000
# 50%    2007.000000    37.000000          27.000000
# 75%    2010.000000    63.000000          54.000000
# max    2012.000000   565.000000         741.000000
#
#        CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER         RAPE  CUSTODIAL_RAPE  \
# count                                8609.000000  8609.000000     8609.000000
# mean                                    5.284818    28.523754        0.003020
# std                                    10.269134    36.397612        0.079146
# min                                     0.000000     0.000000        0.000000
# 25%                                     0.000000     8.000000        0.000000
# ...

# %%
#DISTRICT WISE YEARLY CRIME




w=data
r=w['STATE_UT']
t=[]
for row in r:
    if row not in t:
        t.append(row)
print(t)


a=input('Enter the state ----------\n\n')
x=data.loc[data['STATE_UT']==a]
z=x['DISTRICT']
e=[]
for row in z:
    if row not in e:
        e.append(row)
print(e)

    
b=input('Enter the DISTRICT ----------\n\n')
y=data.loc[(data['STATE_UT']==a) & (data['DISTRICT']==b)]



y['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']
print(y['YEAR'],'\n',y['TOTAL'])
des=y['TOTAL'].describe()
plt.plot(y['YEAR'],y['TOTAL'])
print('\n\nDescription of the data\n',des)
plt.xlabel('YEAR')
plt.ylabel('CRIME COMMITTED')
p=y.groupby(['DISTRICT'])['TOTAL'].max()
m=y.groupby(['DISTRICT'])['TOTAL'].min()
print('\n\n\n','MAXIMUM CRIME IN ',p,'\n\n\n','MINIMUM CRIME IN ',m,'\n\n\n')
# Out:
# ['A & N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI UT', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL']
# Enter the state ----------
#
# ANDHRA PRADESH
# ...

# %%
#Yearly Crime rate




a=2001
z=[]
u=[]
while a<2013:
    y=data.loc[(data['YEAR']==a)]
    y['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']
    x=y['TOTAL'].sum(axis=0)
    z.append(x)
    u.append(a)
    print('Total crime in ',a,' ',x,'\n\n\n\n')
    a=a+1
plt.plot(u,z)
print(des)
plt.xlabel('YEAR')
plt.ylabel('CRIMES')
# Out:
# D:\New folder\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# Total crime in  2001   3960033
#
#
#
#
# Total crime in  2002   3962970
#
#
#
#
# Total crime in  2003   3825314
#
#
#
#
# Total crime in  2004   4106625
#
#
#
#
# Total crime in  2005   4091839
#
#
#
#
# Total crime in  2006   4209768
#
#
#
#
# Total crime in  2007   4444140
#
#
#
#
# Total crime in  2008   4674847
#
#
#
#
# Total crime in  2009   4747380
#
#
#
#
# Total crime in  2010   4969973
#
#
#
#
# Total crime in  2011   5194764
#
#
#
#
# Total crime in  2012   5319580
#
#
#
#
# count      10.00000
# mean     1583.70000
# std       304.98745
# min      1209.00000
# ...

# %%
#State wise Yearly crime



w=data
r=w['STATE_UT']
t=[]
for row in r:
    if row not in t:
        t.append(row)
print(t)

a=input('Enter the state ----------\n\n')
x=data.loc[data['STATE_UT']==a]
x['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']


b=2001
z=[]
u=[]
while b<2013:
    y=data.loc[(data['YEAR']==b)& (data['STATE_UT']==a)]
    y['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']
    x=y['TOTAL'].sum(axis=0)
    z.append(x)
    u.append(b)
    print('Total crime in ',b,'\n',x,'\n\n\n')
    b=b+1
plt.plot(u,z)
#l=0
#df1 = z.DataFrame(z.values.reshape(-1, 12), columns=cols)
new_series = pd.Series(z)
des=new_series.describe()
print('Description of the data\n',des)
plt.xlabel('YEAR')
plt.ylabel(a)
# Out:
# ['A & N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI UT', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL']
# Enter the state ----------
#
# ANDHRA PRADESH
# Total crime in  2001
#  278982
#
#
#
# Total crime in  2002
#  308746
#
#
#
# Total crime in  2003
#  339741
#
#
#
# Total crime in  2004
#  343632
#
#
#
# Total crime in  2005
#  340571
#
#
#
# Total crime in  2006
#  374407
#
#
#
# Total crime in  2007
#  377732
#
#
#
# Total crime in  2008
#  387139
#
#
#
# Total crime in  2009
#  388720
#
#
#
# Total crime in  2010
#  393047
#
#
#
# Total crime in  2011
#  411423
#
#
#
# Total crime in  2012
#  415730
#
#
#
# ...

# %%
#MAX MIN crime rate State wise



w=data
r=w['STATE_UT']
t=[]
for row in r:
    if row not in t:
        t.append(row)
print(t)
t[34]
z=0
uyx=[]
uym=[]
#newy11=[]
#newy12=[]
while z<35:
    
    print(t[z])
    a=t[z]
    
    
    
    x=data.loc[data['STATE_UT']==a]
    x['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']


    b=2001
    o=[]
    u=[]
    g=0
    while b<2013:
        y=data.loc[(data['YEAR']==b)& (data['STATE_UT']==a)]
        y['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']
        x=y['TOTAL'].sum(axis=0)
        o.append(x)
        u.append(b)
        #print('Total crime in ',b,'\n\n\n\n',x)
        b=b+1
        
    ch=0
    ce=100000000000000000
    
    ma=0
    ye=0
    while ma<12:
        if ch<o[ma]:
            mae=o[ma]
            ch=o[ma]
            ye=u[ma]
        
        
        
        if ce>o[ma]:
            maw=o[ma]
            ce=o[ma]
            yr=u[ma]
        ma=ma+1
    
    print('\nThe maximum crime rate was:--------\n',mae ,'in ',ye)
    print('\nThe minimum crime rate was:--------\n',maw ,'in ',yr)
    uyx.append(mae)
    uym.append(maw)
    #newy11.append(ye)
    #newy12.append(yr)
    z=z+1
    print('\n\n\n')
    plt.plot(u,o)

#new_ye=pd.Series(newy11)
#new_yr=pd.Series(newy12)
new_series = pd.Series(uyx)
des1=new_series.describe()
new_series1 = pd.Series(uym)
des2=new_series1.describe()
print('\nDescription of Maximum crime of all states \n\n',des1)
print('\nDescription of Minimum crime of all states \n\n',des2)
#rt=0
#new=0
#new1=1000000
#for rt>35:
    
#    if new>uyx[rt]:
#        new=uyx[rt]
#        newy=newy11[rt]
#    if new1<uym[rt]:
#        new1=uym[rt]
#        newy14=newy12[rt]
#print()
# Out:
# ['A & N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI UT', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL']
# A & N ISLANDS
# D:\New folder\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# D:\New folder\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# ...

# %%
#MAX MIN crime rate State wise



w=data
r=w['STATE_UT']
t=[]
for row in r:
    if row not in t:
        t.append(row)
print(t)
t[34]
z=0
uyx=[]
uym=[]
newy11=[]
newy12=[]
while z<35:
    
    print(t[z])
    a=t[z]
    
    
    
    x=data.loc[data['STATE_UT']==a]
    x['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']


    b=2001
    o=[]
    u=[]
    g=0
    while b<2013:
        y=data.loc[(data['YEAR']==b)& (data['STATE_UT']==a)]
        y['TOTAL']=data['MURDER']+data['ATTEMPT_TO_MURDER']+data['CULPABLE_HOMICIDE_NOT_AMOUNTING_TO_MURDER']+data['RAPE']+data['CUSTODIAL_RAPE']+data['OTHER_RAPE']+data['KIDNAPPING_&_ABDUCTION']+data['KIDNAPPING_AND_ABDUCTION_OF_WOMEN_AND_GIRLS']+data['KIDNAPPING_AND_ABDUCTION_OF_OTHERS']+data['DACOITY']+data['PREPARATION_AND_ASSEMBLY_FOR_DACOITY']+data['ROBBERY']+data['BURGLARY']+data['THEFT']+data['AUTO_THEFT']+data['OTHER_THEFT']+data['RIOTS']+data['CRIMINAL_BREACH_OF_TRUST']+data['CHEATING']+data['COUNTERFIETING']+data['ARSON']+data['HURT_GREVIOUS HURT']+data['DOWRY_DEATHS']+data['ASSAULT_ON_WOMEN_WITH_INTENT_TO_OUTRAGE_HER_MODESTY']+data['INSULT_TO_MODESTY_OF_WOMEN']+data['CRUELTY_BY_HUSBAND_OR_HIS_RELATIVES']+data['IMPORTATION_OF_GIRLS_FROM_FOREIGN_COUNTRIES']+data['CAUSING_DEATH_BY_NEGLIGENCE']+data['OTHER_IPC_CRIMES']+data['TOTAL_IPC_CRIMES']
        x=y['TOTAL'].sum(axis=0)
        o.append(x)
        u.append(b)
        #print('Total crime in ',b,'\n\n\n\n',x)
        b=b+1
     
    ch=0
    ce=100000000000000000
    
    ma=0
    ye=0
    while ma<12:
        if ch<o[ma]:
            mae=o[ma]
            ch=o[ma]
            ye=u[ma]
        
        
        
        if ce>o[ma]:
            maw=o[ma]
            ce=o[ma]
            yr=u[ma]
        ma=ma+1
    
    #print('\nThe maximum crime rate was:--------\n',mae ,'in ',ye)
    #print('\nThe minimum crime rate was:--------\n',maw ,'in ',yr)
    uyx.append(mae)
    uym.append(maw)
    newy11.append(ye)
    newy12.append(yr)
    z=z+1
    print('\n\n\n')
    plt.plot(u,o)

new_ye=pd.Series(newy11)
new_yr=pd.Series(newy12)
new_series = pd.Series(uyx)
des1=new_series.describe()
new_series1 = pd.Series(uym)
des2=new_series1.describe()
print('\nDescription of Maximum crime of all states \n\n',des1)
print('\nDescription of Minimum crime of all states \n\n',des2)
print(new_ye,new_yr,new_series,new_series1)
rt=0
new=[]
new1=[]
newy=0
newy14=0

for rows in new_series:
        new.append(row)
        #newy=newy_ye[rt]
for rows in new_series1:
        new1.append(row)
        #newy14=newy_yr[rt]
print(new,newy,uyx,uym)
# Out:
# ['A & N ISLANDS', 'ANDHRA PRADESH', 'ARUNACHAL PRADESH', 'ASSAM', 'BIHAR', 'CHANDIGARH', 'CHHATTISGARH', 'D & N HAVELI', 'DAMAN & DIU', 'DELHI UT', 'GOA', 'GUJARAT', 'HARYANA', 'HIMACHAL PRADESH', 'JAMMU & KASHMIR', 'JHARKHAND', 'KARNATAKA', 'KERALA', 'LAKSHADWEEP', 'MADHYA PRADESH', 'MAHARASHTRA', 'MANIPUR', 'MEGHALAYA', 'MIZORAM', 'NAGALAND', 'ODISHA', 'PUDUCHERRY', 'PUNJAB', 'RAJASTHAN', 'SIKKIM', 'TAMIL NADU', 'TRIPURA', 'UTTAR PRADESH', 'UTTARAKHAND', 'WEST BENGAL']
# A & N ISLANDS
#
#
#
#
# ANDHRA PRADESH
# C:\Users\Prashant\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# C:\Users\Prashant\Anaconda3\lib\site-packages\ipykernel_launcher.py:35: SettingWithCopyWarning:
# ...
